# %%
import pandas as pd
# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import collections
from scipy import stats

# %%
df = pd.read_csv('cleaned_features.csv').iloc[:,3:].dropna().astype(float)
df.columns
# Out:
# Index(['Thriller', 'Comedy', 'Documentary', 'Fantasy/Fairy tales', 'Action',
#        'Music', 'Classical music', 'Rock', 'Opera', 'Swing, Jazz',
#        'Art exhibitions', 'Science and technology', 'Religion',
#        'Countryside, outdoors', 'Fun with friends', 'Dancing', 'Law',
#        'Musical instruments', 'Prioritising workload', 'Writing notes',
#        'Funniness', 'Fake', 'Decision making', 'Empathy', 'Judgment calls',
#        'Loneliness', 'Number of friends', 'Appearence and gestures',
#        'Personality', 'Assertiveness', 'Workaholism', 'Healthy eating',
#        'Thinking ahead', 'Finances', 'Spending on looks', 'Age', 'Weight',
#        'Number of siblings', 'Education', 'Spending on gadgets', 'Height',
#        'Happiness in life'],
#       dtype='object')

# %% [markdown]
# Let's calculate the correlations

# %%
#x axis - column
#y axis r value

columns = []
values = []
_dict = collections.defaultdict()
testColumn = 'Workaholism'


for column in df.columns:
  temp = np.corrcoef(df[testColumn], df[column])[0][1] # Get cor coef for each feature
  _dict[column] = temp
    
for w in sorted(_dict, key=_dict.get, reverse=True):
    columns.append(w)
    values.append(_dict[w])
    
def plot(x, y, figsize):
    fig, ax = plt.subplots(figsize=figsize)
    ax.set_title(testColumn, size = 80)
    sns.barplot(x=y, y=x, orient = 'h')
    ax.set_ylabel("Correlation coefficients")
    #plt.xlabel(xlabel = columns, size = 10)
    sns.set(font_scale=7)


plot(columns,values, figsize=(50, 100))

# %% [markdown]
# We see as expected that there is a strong correlation with ‘Prioritising workload’, and ‘thinking ahead’. We also see some intuitive negative correlations with ‘fun with friends’. Finally the lack of correlation between some of the features like ‘education’ is somewhat surprising.

# %% [markdown]
# Let's see if our results are significant with a t-test. First let's divide the results into those with a large affinity towards workaholism and those who have a small

# %%
large = df[df['Workaholism'] > 3]
small = df[df['Workaholism'] < 3]
print('number of large ' +  str(len(large)))
print('number of small ' + str(len(small)))
# Out:
# number of large 344
# number of small 372

# %% [markdown]
# Let the null hypothesis be that there is no significant difference between prioritising workload whether coming from the big sample or the small.
# Let our significance level be .05
# We can apply the CLT since the distributions are normal.

# %% [markdown]
# First let's see what the difference actually is

# %%
sigLevel = .05
largeMean = large['Prioritising workload'].mean()
smallMean = small['Prioritising workload'].mean()
print('The large mean is ' + str(largeMean) + ' and the small mean is ' + str(smallMean))
print('the total difference is ' + str(largeMean - smallMean))
# Out:
# The large mean is 3.1744186046511627 and the small mean is 2.0591397849462365
# the total difference is 1.1152788197049261

# %% [markdown]
# Now let's see if this difference is significant

# %%
stats.ttest_ind(large['Prioritising workload'],small['Prioritising workload'])
# Out:
# Ttest_indResult(statistic=13.234471725779063, pvalue=6.475002827704593e-36)

# %% [markdown]
# This p statistic is very small. It is therefore likely that this correlation is significant.
# Let's see what this difference actually is.

# %% [markdown]
# Let's calculate the p values more efficently in a loop.

# %%
sigColumns = []
count = 0

for i, column in enumerate(columns):
    #if values[i] < .05 # If there is a significant correlation
      print('for the column ' + str(column))
      print('the correlation coeficent is  ' + str(values[i]))
      largeMean = large[column].mean()
      smallMean = small[column].mean()
      #print('The large mean is ' + str(largeMean) + ' and the small mean is ' + str(smallMean))
      print('the total difference is ' + str(largeMean - smallMean))
      stat, pVal = stats.ttest_ind(large[column],small[column])
      print('the p val is ' + str(pVal))
      print()
      count = count +1
      if pVal < .05:
        sigColumns.append(column)
# Out:
# for the column Workaholism
# the correlation coeficent is  0.9999999999999998
# the total difference is 2.8473278145407006
# the p val is 0.0
#
# for the column Prioritising workload
# the correlation coeficent is  0.41420185325258213
# the total difference is 1.1152788197049261
# the p val is 6.475002827704593e-36
#
# for the column Writing notes
# the correlation coeficent is  0.4064926199300132
# the total difference is 1.2462803200800203
# the p val is 6.337279200708932e-33
#
# for the column Thinking ahead
# the correlation coeficent is  0.2840703459444896
# the total difference is 0.7066269732775794
# the p val is 1.1054448940359247e-16
#
# for the column Healthy eating
# the correlation coeficent is  0.2298608793308776
# the total difference is 0.4499319343241961
# the p val is 2.315941762361617e-10
#
# for the column Classical music
# the correlation coeficent is  0.21242815311395005
# the total difference is 0.5841531108101048
# the p val is 5.093402902587767e-10
#
# for the column Documentary
# the correlation coeficent is  0.2019342319059226
# the total difference is 0.5393827873135955
# the p val is 1.9818984419300696e-10
#
# for the column Science and technology
# the correlation coeficent is  0.20062339049201064
# the total difference is 0.6009939984996246
# the p val is 2.819829674677941e-10
#
# for the column Opera
# the correlation coeficent is  0.2000828535134808
# the total difference is 0.5440421366491277
# the p val is 4.453515815225056e-10
#
# for the column Art exhibitions
# the correlation coeficent is  0.19261247438893428
# the total difference is 0.5553263315828953
# the p val is 1.8702244423015685e-08
#
# for the column Swing, Jazz
# the correlation coeficent is  0.15982205069127647
# the total difference is 0.4481632733880683
# the p val is 2.1578188572851223e-06
#
# for the column Law
# the correlation coeficent is  0.12459298247275657
# the total difference is 0.39450487621905506
# the p val is 2.6090784335864363e-05
#
# for the column Finances
# the correlation coeficent is  0.1219263744900019
# the total difference is 0.33468418619053963
# the p val is 0.00010183267712540083
#
# for the column Countryside, outdoors
# the correlation coeficent is  0.11907803455258983
# the total difference is 0.30138784696174037
# the p val is 0.0009924305135788386
#
# for the column Religion
# the correlation coeficent is  0.10687170568065515
# the total difference is 0.3268629657414355
# the p val is 0.001276831236640253
#
# for the column Age
# the correlation coeficent is  0.10625688862304707
# the total difference is 0.644089268827674
# the p val is 0.0022591076340259717
#
# for the column Dancing
# the correlation coeficent is  0.10006321574690949
# the total difference is 0.3199237309327332
# the p val is 0.0035282500697427707
#
# for the column Decision making
# the correlation coeficent is  0.09255616135966054
# the total difference is 0.21180295073768463
# the p val is 0.021981082971950998
#
# for the column Musical instruments
# the correlation coeficent is  0.08825532466646994
# the total difference is 0.3588397099274818
# the p val is 0.001570468570144673
#
# for the column Happiness in life
# the correlation coeficent is  0.08168383765798742
# the total difference is 0.18535883970992773
# the p val is 0.0028483471160389313
#
# for the column Appearence and gestures
# the correlation coeficent is  0.08028536467082881
# the total difference is 0.17485621405351326
# the p val is 0.012895148729138198
#
# for the column Empathy
# the correlation coeficent is  0.04699698464116832
# the total difference is 0.11665416354088487
# the p val is 0.17191287924083934
#
# for the column Rock
# the correlation coeficent is  0.041916785484427746
# the total difference is 0.11430634052935584
# the p val is 0.20149170354351456
#
# for the column Assertiveness
# the correlation coeficent is  0.03062158728015642
# the total difference is 0.09750103076364347
# the p val is 0.24575558718016663
#
# for the column Music
# the correlation coeficent is  0.02410205555290854
# the total difference is 0.033168576404279726
# the p val is 0.5099897500904353
#
# for the column Funniness
# the correlation coeficent is  0.018544902299182913
# the total difference is 0.06214053513378337
# the p val is 0.4706326720397366
#
# for the column Education
# the correlation coeficent is  0.0012741574318118065
# the total difference is -0.008127031757939385
# the p val is 0.8936086807553476
#
# for the column Fake
# the correlation coeficent is  0.0005809774246523212
# the total difference is 0.00418854713678396
# the p val is 0.9575203557403541
#
# for the column Number of siblings
# the correlation coeficent is  -0.00039984936377227605
# the total difference is 0.03547329187874659
# the p val is 0.6449307393085313
#
# for the column Fantasy/Fairy tales
# the correlation coeficent is  -0.0011534087080593328
# the total difference is -0.0579754856787682
# the p val is 0.5205569197574325
#
# for the column Judgment calls
# the correlation coeficent is  -0.0032933756354397393
# the total difference is 0.03241435358839695
# the p val is 0.6534281198989249
#
# for the column Loneliness
# the correlation coeficent is  -0.008083748074952433
# the total difference is -0.048293323330832916
# the p val is 0.5746355516548861
#
# for the column Personality
# the correlation coeficent is  -0.009161027184140537
# the total difference is -0.005310969889589678
# the p val is 0.9122815431636838
#
# for the column Number of friends
# the correlation coeficent is  -0.02214566206455646
# the total difference is -0.03660290072518135
# the p val is 0.6471125189782025
#
# for the column Height
# the correlation coeficent is  -0.031812135412161276
# the total difference is -0.5938102265465091
# the p val is 0.44156280237137957
#
# for the column Spending on gadgets
# the correlation coeficent is  -0.033294883265629426
# the total difference is -0.0349149787446863
# the p val is 0.72110075698142
#
# for the column Weight
# the correlation coeficent is  -0.03549990509017219
# the total difference is -0.4042049653827604
# the p val is 0.7017970965796942
#
# for the column Comedy
# the correlation coeficent is  -0.03832943228611748
# the total difference is -0.0801450362590641
# the p val is 0.1627181172508113
#
# for the column Spending on looks
# the correlation coeficent is  -0.04142454665478268
# the total difference is -0.12770111594432887
# the p val is 0.16290494433287167
#
# for the column Fun with friends
# the correlation coeficent is  -0.06189822847337873
# the total difference is -0.09052263065766475
# the p val is 0.10419827448447926
#
# for the column Thriller
# the correlation coeficent is  -0.07532809208181383
# the total difference is -0.18480651505790258
# the p val is 0.03991359816336532
#
# for the column Action
# the correlation coeficent is  -0.10239963391271877
# the total difference is -0.2390048466977852
# the p val is 0.009242819376110399

# %%
print("The columns with significant correlations are ")
print(sigColumns)
# Out:
# The columns with significant correlations are
# ['Workaholism', 'Prioritising workload', 'Writing notes', 'Thinking ahead', 'Healthy eating', 'Classical music', 'Documentary', 'Science and technology', 'Opera', 'Art exhibitions', 'Swing, Jazz', 'Law', 'Finances', 'Countryside, outdoors', 'Religion', 'Age', 'Dancing', 'Decision making', 'Musical instruments', 'Happiness in life', 'Appearence and gestures', 'Thriller', 'Action']

# %%
print(len(sigColumns))
# Out:
# 23

# %% [markdown]
# Let's now find a 95 percent confidence interval for fun with friends

# %%
small = small.iloc[:344]
largeMean = large['Fun with friends'].mean()
smallMean = small['Fun with friends'].mean()
meanDif = largeMean - smallMean
difArray = large[['Fun with friends']] - small[['Fun with friends']]
std = difArray.std()
large = large.reset_index()
small = small.reset_index()

# %%
CriticalVal = 1.96
Error = std/np.sqrt(len(difArray))
marginOFError = CriticalVal * Error
print('A 95 percent CI is (' + str(meanDif - Error) + ', ' + str(meanDif+Error))
# Out:
# A 95 percent CI is (Fun with friends   -0.144211
# dtype: float64, Fun with friends   -0.030207
# dtype: float64

# %% [markdown]
# The CI represents the range that the true parameter can be 95 percent of the time. Because 0 is not included within this range, we see that it is unlikely that there is no correlation.
# It's worth noting though that the max of the CI, -.03, is not a very strong correlation.
